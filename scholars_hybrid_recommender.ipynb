# %% [markdown]
# # ScholarS Hybrid Course Recommendation
#
# Checkpoint 2 prototype: blend collaborative filtering with content features. The current genre features are a stand-in for course category, level, and skills until real ScholarS metadata is provided.

# %%
from hybrid_recommender import evaluate

metrics = evaluate()
metrics

# %% [markdown]
# ## Offline evaluation
#
# Compare popularity baseline and hybrid Hit Rate@5 and NDCG@5. These substitute-data metrics must be replaced with ScholarS learner-course results before client reporting.
