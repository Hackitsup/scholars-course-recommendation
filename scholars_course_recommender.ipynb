# %% [markdown]
# # ScholarS Course Recommendation Prototype
#
# This notebook demonstrates the ScholarS course recommendation workflow with substitute ratings. Replace the substitute data with real learner-course history before reporting client metrics.

# %%
from recommender_demo import evaluate

metrics = evaluate()
metrics

# %% [markdown]
# ## Interpretation
#
# Compare the measured popularity baseline and SVD Hit Rate@5 and NDCG@5. These are prototype results from substitute ratings, not ScholarS learner-course results.
